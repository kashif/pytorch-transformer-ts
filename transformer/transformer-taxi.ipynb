# %%
from itertools import islice

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib.dates as mdates

import pandas as pd
from sklearn.manifold import TSNE

# %%
from gluonts.dataset.repository.datasets import get_dataset
from gluonts.dataset.common import ListDataset
from gluonts.evaluation import make_evaluation_predictions, Evaluator
from gluonts.torch.distributions import NegativeBinomialOutput

from pytorch_lightning.loggers import CSVLogger
from datasets import load_dataset

from estimator import TransformerEstimator

# %%
dataset = get_dataset("taxi_30min")

# %%
estimator = TransformerEstimator(
        freq=dataset.metadata.freq,
        prediction_length=dataset.metadata.prediction_length,
        context_length=dataset.metadata.prediction_length*6,
        
        scaling=True,
        num_feat_static_cat=len(dataset.metadata.feat_static_cat),
        cardinality=[int(cat_feat_info.cardinality) for cat_feat_info in dataset.metadata.feat_static_cat],
        embedding_dimension=[5],
        
        nhead=2,
        num_encoder_layers=4,
        num_decoder_layers=2,
        dim_feedforward=16,
        activation="gelu",
        distr_output=NegativeBinomialOutput(),
        
        batch_size=256,
        num_batches_per_epoch=200,
        trainer_kwargs=dict(gpus="1", max_epochs=100, logger=CSVLogger(".", "lightning_logs/")),
    )

# %%
predictor = estimator.train(
        training_data=dataset.train,
        shuffle_buffer_length=1024,
        num_workers=8,
        cache_data=True,
    )
# Out:
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/utilities/parsing.py:262: UserWarning: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
#   rank_zero_warn(
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:446: LightningDeprecationWarning: Setting `Trainer(gpus='1')` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices='1')` instead.
#   rank_zero_deprecation(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:108: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type             | Params
# -------------------------------------------
# 0 | model | TransformerModel | 92.6 K
# -------------------------------------------
# 92.6 K    Trainable params
# 0         Non-trainable params
# 92.6 K    Total params
# 0.370     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 200: 'train_loss' reached 3.06217 (best 3.06217), saving model to './lightning_logs/version_409/checkpoints/epoch=0-step=200.ckpt' as top 1
# Epoch 1, global step 400: 'train_loss' reached 2.53445 (best 2.53445), saving model to './lightning_logs/version_409/checkpoints/epoch=1-step=400.ckpt' as top 1
# Epoch 2, global step 600: 'train_loss' reached 2.47591 (best 2.47591), saving model to './lightning_logs/version_409/checkpoints/epoch=2-step=600.ckpt' as top 1
# Epoch 3, global step 800: 'train_loss' reached 2.45317 (best 2.45317), saving model to './lightning_logs/version_409/checkpoints/epoch=3-step=800.ckpt' as top 1
# Epoch 4, global step 1000: 'train_loss' reached 2.43429 (best 2.43429), saving model to './lightning_logs/version_409/checkpoints/epoch=4-step=1000.ckpt' as top 1
# Epoch 5, global step 1200: 'train_loss' reached 2.42525 (best 2.42525), saving model to './lightning_logs/version_409/checkpoints/epoch=5-step=1200.ckpt' as top 1
# Epoch 6, global step 1400: 'train_loss' reached 2.41807 (best 2.41807), saving model to './lightning_logs/version_409/checkpoints/epoch=6-step=1400.ckpt' as top 1
# Epoch 7, global step 1600: 'train_loss' reached 2.41316 (best 2.41316), saving model to './lightning_logs/version_409/checkpoints/epoch=7-step=1600.ckpt' as top 1
# Epoch 8, global step 1800: 'train_loss' reached 2.40740 (best 2.40740), saving model to './lightning_logs/version_409/checkpoints/epoch=8-step=1800.ckpt' as top 1
# Epoch 9, global step 2000: 'train_loss' reached 2.40576 (best 2.40576), saving model to './lightning_logs/version_409/checkpoints/epoch=9-step=2000.ckpt' as top 1
# Epoch 10, global step 2200: 'train_loss' reached 2.40202 (best 2.40202), saving model to './lightning_logs/version_409/checkpoints/epoch=10-step=2200.ckpt' as top 1
# Epoch 11, global step 2400: 'train_loss' reached 2.39732 (best 2.39732), saving model to './lightning_logs/version_409/checkpoints/epoch=11-step=2400.ckpt' as top 1
# Epoch 12, global step 2600: 'train_loss' was not in top 1
# Epoch 13, global step 2800: 'train_loss' reached 2.39658 (best 2.39658), saving model to './lightning_logs/version_409/checkpoints/epoch=13-step=2800.ckpt' as top 1
# Epoch 14, global step 3000: 'train_loss' reached 2.39596 (best 2.39596), saving model to './lightning_logs/version_409/checkpoints/epoch=14-step=3000.ckpt' as top 1
# Epoch 15, global step 3200: 'train_loss' reached 2.39392 (best 2.39392), saving model to './lightning_logs/version_409/checkpoints/epoch=15-step=3200.ckpt' as top 1
# Epoch 16, global step 3400: 'train_loss' reached 2.39067 (best 2.39067), saving model to './lightning_logs/version_409/checkpoints/epoch=16-step=3400.ckpt' as top 1
# Epoch 17, global step 3600: 'train_loss' reached 2.39003 (best 2.39003), saving model to './lightning_logs/version_409/checkpoints/epoch=17-step=3600.ckpt' as top 1
# Epoch 18, global step 3800: 'train_loss' reached 2.38988 (best 2.38988), saving model to './lightning_logs/version_409/checkpoints/epoch=18-step=3800.ckpt' as top 1
# Epoch 19, global step 4000: 'train_loss' was not in top 1
# Epoch 20, global step 4200: 'train_loss' reached 2.38674 (best 2.38674), saving model to './lightning_logs/version_409/checkpoints/epoch=20-step=4200.ckpt' as top 1
# Epoch 21, global step 4400: 'train_loss' reached 2.38460 (best 2.38460), saving model to './lightning_logs/version_409/checkpoints/epoch=21-step=4400.ckpt' as top 1
# Epoch 22, global step 4600: 'train_loss' was not in top 1
# Epoch 23, global step 4800: 'train_loss' reached 2.38250 (best 2.38250), saving model to './lightning_logs/version_409/checkpoints/epoch=23-step=4800.ckpt' as top 1
# Epoch 24, global step 5000: 'train_loss' reached 2.38088 (best 2.38088), saving model to './lightning_logs/version_409/checkpoints/epoch=24-step=5000.ckpt' as top 1
# Epoch 25, global step 5200: 'train_loss' was not in top 1
# Epoch 26, global step 5400: 'train_loss' was not in top 1
# Epoch 27, global step 5600: 'train_loss' was not in top 1
# Epoch 28, global step 5800: 'train_loss' was not in top 1
# Epoch 29, global step 6000: 'train_loss' reached 2.37992 (best 2.37992), saving model to './lightning_logs/version_409/checkpoints/epoch=29-step=6000.ckpt' as top 1
# Epoch 30, global step 6200: 'train_loss' was not in top 1
# Epoch 31, global step 6400: 'train_loss' reached 2.37805 (best 2.37805), saving model to './lightning_logs/version_409/checkpoints/epoch=31-step=6400.ckpt' as top 1
# Epoch 32, global step 6600: 'train_loss' was not in top 1
# Epoch 33, global step 6800: 'train_loss' was not in top 1
# Epoch 34, global step 7000: 'train_loss' was not in top 1
# Epoch 35, global step 7200: 'train_loss' reached 2.37800 (best 2.37800), saving model to './lightning_logs/version_409/checkpoints/epoch=35-step=7200.ckpt' as top 1
# Epoch 36, global step 7400: 'train_loss' reached 2.37680 (best 2.37680), saving model to './lightning_logs/version_409/checkpoints/epoch=36-step=7400.ckpt' as top 1
# Epoch 37, global step 7600: 'train_loss' was not in top 1
# Epoch 38, global step 7800: 'train_loss' reached 2.37538 (best 2.37538), saving model to './lightning_logs/version_409/checkpoints/epoch=38-step=7800.ckpt' as top 1
# Epoch 39, global step 8000: 'train_loss' was not in top 1
# Epoch 40, global step 8200: 'train_loss' was not in top 1
# Epoch 41, global step 8400: 'train_loss' reached 2.37367 (best 2.37367), saving model to './lightning_logs/version_409/checkpoints/epoch=41-step=8400.ckpt' as top 1
# Epoch 42, global step 8600: 'train_loss' reached 2.37259 (best 2.37259), saving model to './lightning_logs/version_409/checkpoints/epoch=42-step=8600.ckpt' as top 1
# Epoch 43, global step 8800: 'train_loss' was not in top 1
# Epoch 44, global step 9000: 'train_loss' reached 2.37257 (best 2.37257), saving model to './lightning_logs/version_409/checkpoints/epoch=44-step=9000.ckpt' as top 1
# Epoch 45, global step 9200: 'train_loss' was not in top 1
# Epoch 46, global step 9400: 'train_loss' was not in top 1
# Epoch 47, global step 9600: 'train_loss' was not in top 1
# Epoch 48, global step 9800: 'train_loss' reached 2.37162 (best 2.37162), saving model to './lightning_logs/version_409/checkpoints/epoch=48-step=9800.ckpt' as top 1
# Epoch 49, global step 10000: 'train_loss' reached 2.37074 (best 2.37074), saving model to './lightning_logs/version_409/checkpoints/epoch=49-step=10000.ckpt' as top 1
# Epoch 50, global step 10200: 'train_loss' was not in top 1
# Epoch 51, global step 10400: 'train_loss' reached 2.36973 (best 2.36973), saving model to './lightning_logs/version_409/checkpoints/epoch=51-step=10400.ckpt' as top 1
# Epoch 52, global step 10600: 'train_loss' reached 2.36938 (best 2.36938), saving model to './lightning_logs/version_409/checkpoints/epoch=52-step=10600.ckpt' as top 1
# Epoch 53, global step 10800: 'train_loss' reached 2.36842 (best 2.36842), saving model to './lightning_logs/version_409/checkpoints/epoch=53-step=10800.ckpt' as top 1
# Epoch 54, global step 11000: 'train_loss' was not in top 1
# Epoch 55, global step 11200: 'train_loss' was not in top 1
# Epoch 56, global step 11400: 'train_loss' was not in top 1
# Epoch 57, global step 11600: 'train_loss' was not in top 1
# Epoch 58, global step 11800: 'train_loss' was not in top 1
# Epoch 59, global step 12000: 'train_loss' reached 2.36790 (best 2.36790), saving model to './lightning_logs/version_409/checkpoints/epoch=59-step=12000.ckpt' as top 1
# Epoch 60, global step 12200: 'train_loss' was not in top 1
# Epoch 61, global step 12400: 'train_loss' reached 2.36597 (best 2.36597), saving model to './lightning_logs/version_409/checkpoints/epoch=61-step=12400.ckpt' as top 1
# Epoch 62, global step 12600: 'train_loss' was not in top 1
# Epoch 63, global step 12800: 'train_loss' was not in top 1
# Epoch 64, global step 13000: 'train_loss' was not in top 1
# Epoch 65, global step 13200: 'train_loss' was not in top 1
# Epoch 66, global step 13400: 'train_loss' was not in top 1
# Epoch 67, global step 13600: 'train_loss' reached 2.36487 (best 2.36487), saving model to './lightning_logs/version_409/checkpoints/epoch=67-step=13600.ckpt' as top 1
# Epoch 68, global step 13800: 'train_loss' was not in top 1
# Epoch 69, global step 14000: 'train_loss' was not in top 1
# Epoch 70, global step 14200: 'train_loss' was not in top 1
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py:48: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/utilities/parsing.py:262: UserWarning: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
#   rank_zero_warn(

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=dataset.test,
    predictor=predictor,
)

# %%
forecasts = list(forecast_it)

# %%
tss = list(ts_it)

# %%
evaluator = Evaluator()

# %%
agg_metrics, ts_metrics = evaluator(iter(tss), iter(forecasts))
# Out:
# Running evaluation: 67984it [00:00, 147556.81it/s]
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:170: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)

# %%
agg_metrics
# Out:
# {'MSE': 23.006624651408654,
#  'abs_error': 4843095.0,
#  'abs_target_sum': 12453360.0,
#  'abs_target_mean': 7.632531183807954,
#  'seasonal_error': 3.785588038176638,
#  'MASE': 0.7902977997343632,
#  'MAPE': 0.6323609114369652,
#  'sMAPE': 0.594651401476542,
#  'MSIS': 6.090021557510274,
#  'QuantileLoss[0.1]': 2072715.4000000004,
#  'Coverage[0.1]': 0.09051271867890483,
#  'QuantileLoss[0.2]': 3239305.2,
#  'Coverage[0.2]': 0.15741019945869617,
#  'QuantileLoss[0.3]': 4057224.4,
#  'Coverage[0.3]': 0.22986781203420417,
#  'QuantileLoss[0.4]': 4586851.2,
#  'Coverage[0.4]': 0.3089722091472504,
#  'QuantileLoss[0.5]': 4843095.0,
#  'Coverage[0.5]': 0.39535405389503414,
#  'QuantileLoss[0.6]': 4826458.800000001,
#  'Coverage[0.6]': 0.47970417058915826,
#  'QuantileLoss[0.7]': 4505249.000000001,
#  'Coverage[0.7]': 0.5816098886012395,
#  'QuantileLoss[0.8]': 3821781.2,
#  'Coverage[0.8]': 0.6912006256374049,
#  'QuantileLoss[0.9]': 2644672.599999999,
#  'Coverage[0.9]': 0.810963486506629,
#  'RMSE': 4.796522141240323,
#  'NRMSE': 0.6284313847830603,
#  'ND': 0.3888986586752491,
#  'wQuantileLoss[0.1]': 0.16643824638491142,
#  'wQuantileLoss[0.2]': 0.2601149569272871,
#  'wQuantileLoss[0.3]': 0.3257935529045976,
#  'wQuantileLoss[0.4]': 0.36832238046599475,
#  'wQuantileLoss[0.5]': 0.3888986586752491,
#  'wQuantileLoss[0.6]': 0.38756277823816226,
#  'wQuantileLoss[0.7]': 0.3617697553110165,
#  'wQuantileLoss[0.8]': 0.3068875548446363,
#  'wQuantileLoss[0.9]': 0.21236618872336455,
#  'mean_absolute_QuantileLoss': 3844150.3111111107,
#  'mean_wQuantileLoss': 0.3086837858305799,
#  'MAE_Coverage': 0.08382275949460875,
#  'OWA': nan}

# %%
plt.figure(figsize=(20, 15))
date_formater = mdates.DateFormatter('%b, %d')
plt.rcParams.update({'font.size': 15})

for idx, (forecast, ts) in islice(enumerate(zip(forecasts, tss)), 9):
    ax = plt.subplot(3, 3, idx+1)

    plt.plot(ts[-4 * dataset.metadata.prediction_length:].to_timestamp(), label="target", )
    forecast.plot( color='g')
    plt.xticks(rotation=60)
    ax.xaxis.set_major_formatter(date_formater)
    ax.set_title(forecast.item_id)

plt.gcf().tight_layout()
plt.legend()
plt.show()

# %%
metrics = pd.read_csv("lightning_logs/version_86/metrics.csv")

# %%
metrics
# Out:
#      train_perplexity  epoch  step  val_loss  train_loss
# 0            2.042362      0    49       NaN         NaN
# 1            2.050069      0    99       NaN         NaN
# 2            2.743227      0   149       NaN         NaN
# 3            2.440984      0   199       NaN         NaN
# 4                 NaN      0   199  4.355846         NaN
# ..                ...    ...   ...       ...         ...
# 295         80.659866     49  9899       NaN         NaN
# 296         82.568138     49  9949       NaN         NaN
# 297         81.211136     49  9999       NaN         NaN
# 298               NaN     49  9999  1.084462         NaN
# 299               NaN     49  9999       NaN    1.707654
#
# [300 rows x 5 columns]

# %%
ax = metrics.train_perplexity.dropna().plot(kind="line")
ax.set_xlabel("training steps")
ax.set_ylabel("perplexity")
# Out:
# Text(0, 0.5, 'perplexity')

# %%
ax = metrics.val_loss.dropna().plot()
ax.set_xlabel("training steps")
ax.set_ylabel("val neg. log likelihood")
# Out:
# Text(0, 0.5, 'val neg. log likelihood')

# %%
X = predictor.prediction_net.vq_vae.embed.cpu()

# %%
X_embedded = TSNE(n_components=2, learning_rate='auto', init='random').fit_transform(X)

# %%
plt.scatter(X_embedded[:,0], X_embedded[:,1], alpha=1.0)
