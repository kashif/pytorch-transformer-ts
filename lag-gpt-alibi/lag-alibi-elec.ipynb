# %%
from itertools import islice

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib.dates as mdates

# %%
from gluonts.dataset.repository.datasets import get_dataset
from gluonts.dataset.common import ListDataset
from gluonts.evaluation import make_evaluation_predictions, Evaluator
from pytorch_lightning.loggers import CSVLogger
from datasets import load_dataset

from estimator import LagGPTAlibiEstimator
# Out:
# [2023-08-08 14:08:52,738] [INFO] [real_accelerator.py:133:get_accelerator] Setting ds_accelerator to cuda (auto detect)

# %%
dataset = get_dataset("electricity")

# %%
estimator = LagGPTAlibiEstimator(
    prediction_length=dataset.metadata.prediction_length,
    context_length=dataset.metadata.prediction_length,
    
    scaling="std",
    # rope_scaling=dict(type="linear", factor=2.0),
    # nhead=2,
    n_layer=4,
    # num_decoder_layers=2,
    # dim_feedforward=16,
    # activation="gelu",
    
    batch_size=64,
    num_batches_per_epoch=100,
    trainer_kwargs=dict(accelerator="gpu", precision="bf16-mixed", max_epochs=50),
    
)

# %%
predictor = estimator.train(
        training_data=dataset.train,
        shuffle_buffer_length=1024,
        cache_data=True,
    )
# Out:
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:70: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# You are using a CUDA device ('NVIDIA GeForce RTX 3090 Ti') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type             | Params
# -------------------------------------------
# 0 | model | LagGPTAlibiModel | 117 K
# -------------------------------------------
# 117 K     Trainable params
# 0         Non-trainable params
# 117 K     Total params
# 0.471     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 100: 'train_loss' reached 5.74067 (best 5.74067), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=0-step=100.ckpt' as top 1
# Epoch 1, global step 200: 'train_loss' reached 5.36387 (best 5.36387), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=1-step=200.ckpt' as top 1
# Epoch 2, global step 300: 'train_loss' was not in top 1
# Epoch 3, global step 400: 'train_loss' reached 5.29572 (best 5.29572), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=3-step=400.ckpt' as top 1
# Epoch 4, global step 500: 'train_loss' reached 5.28518 (best 5.28518), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=4-step=500.ckpt' as top 1
# Epoch 5, global step 600: 'train_loss' reached 5.25221 (best 5.25221), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=5-step=600.ckpt' as top 1
# Epoch 6, global step 700: 'train_loss' reached 5.25162 (best 5.25162), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=6-step=700.ckpt' as top 1
# Epoch 7, global step 800: 'train_loss' reached 5.24294 (best 5.24294), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=7-step=800.ckpt' as top 1
# Epoch 8, global step 900: 'train_loss' reached 5.18201 (best 5.18201), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=8-step=900.ckpt' as top 1
# Epoch 9, global step 1000: 'train_loss' was not in top 1
# Epoch 10, global step 1100: 'train_loss' was not in top 1
# Epoch 11, global step 1200: 'train_loss' was not in top 1
# Epoch 12, global step 1300: 'train_loss' reached 5.18065 (best 5.18065), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=12-step=1300.ckpt' as top 1
# Epoch 13, global step 1400: 'train_loss' was not in top 1
# Epoch 14, global step 1500: 'train_loss' was not in top 1
# Epoch 15, global step 1600: 'train_loss' reached 5.16452 (best 5.16452), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=15-step=1600.ckpt' as top 1
# Epoch 16, global step 1700: 'train_loss' was not in top 1
# Epoch 17, global step 1800: 'train_loss' reached 5.14933 (best 5.14933), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=17-step=1800.ckpt' as top 1
# Epoch 18, global step 1900: 'train_loss' was not in top 1
# Epoch 19, global step 2000: 'train_loss' was not in top 1
# Epoch 20, global step 2100: 'train_loss' was not in top 1
# Epoch 21, global step 2200: 'train_loss' was not in top 1
# Epoch 22, global step 2300: 'train_loss' was not in top 1
# Epoch 23, global step 2400: 'train_loss' reached 5.14091 (best 5.14091), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=23-step=2400.ckpt' as top 1
# Epoch 24, global step 2500: 'train_loss' was not in top 1
# Epoch 25, global step 2600: 'train_loss' reached 5.13777 (best 5.13777), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=25-step=2600.ckpt' as top 1
# Epoch 26, global step 2700: 'train_loss' reached 5.13727 (best 5.13727), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=26-step=2700.ckpt' as top 1
# Epoch 27, global step 2800: 'train_loss' reached 5.11746 (best 5.11746), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=27-step=2800.ckpt' as top 1
# Epoch 28, global step 2900: 'train_loss' was not in top 1
# Epoch 29, global step 3000: 'train_loss' was not in top 1
# Epoch 30, global step 3100: 'train_loss' was not in top 1
# Epoch 31, global step 3200: 'train_loss' was not in top 1
# Epoch 32, global step 3300: 'train_loss' was not in top 1
# Epoch 33, global step 3400: 'train_loss' reached 5.09795 (best 5.09795), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=33-step=3400.ckpt' as top 1
# Epoch 34, global step 3500: 'train_loss' was not in top 1
# Epoch 35, global step 3600: 'train_loss' was not in top 1
# Epoch 36, global step 3700: 'train_loss' was not in top 1
# Epoch 37, global step 3800: 'train_loss' reached 5.08756 (best 5.08756), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=37-step=3800.ckpt' as top 1
# Epoch 38, global step 3900: 'train_loss' was not in top 1
# Epoch 39, global step 4000: 'train_loss' was not in top 1
# Epoch 40, global step 4100: 'train_loss' was not in top 1
# Epoch 41, global step 4200: 'train_loss' was not in top 1
# Epoch 42, global step 4300: 'train_loss' reached 5.07913 (best 5.07913), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=42-step=4300.ckpt' as top 1
# Epoch 43, global step 4400: 'train_loss' was not in top 1
# Epoch 44, global step 4500: 'train_loss' was not in top 1
# Epoch 45, global step 4600: 'train_loss' was not in top 1
# Epoch 46, global step 4700: 'train_loss' was not in top 1
# Epoch 47, global step 4800: 'train_loss' reached 5.07456 (best 5.07456), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=47-step=4800.ckpt' as top 1
# Epoch 48, global step 4900: 'train_loss' was not in top 1
# Epoch 49, global step 5000: 'train_loss' reached 5.06717 (best 5.06717), saving model to '/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=49-step=5000.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=50` reached.

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=dataset.test,
    predictor=predictor,
)

# %%
forecasts = list(forecast_it)

# %%
tss = list(ts_it)

# %%
evaluator = Evaluator()

# %%
agg_metrics, ts_metrics = evaluator(iter(tss), iter(forecasts))
# Out:
# Running evaluation: 2247it [00:00, 34761.35it/s]
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:138: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)

# %%
agg_metrics
# Out:
# {'MSE': 735796.3710572504,
#  'abs_error': 6556604.1308596255,
#  'abs_target_sum': 128632956.0,
#  'abs_target_mean': 2385.272140631954,
#  'seasonal_error': 189.49338196116761,
#  'MASE': 0.6330733120041183,
#  'MAPE': 0.08318090772904012,
#  'sMAPE': 0.09158923415481789,
#  'MSIS': 5.110429238210401,
#  'num_masked_target_values': 0.0,
#  'QuantileLoss[0.1]': 2883595.369536202,
#  'Coverage[0.1]': 0.09243806556890669,
#  'QuantileLoss[0.2]': 4473687.781163108,
#  'Coverage[0.2]': 0.20631211986352174,
#  'QuantileLoss[0.3]': 5541123.902175044,
#  'Coverage[0.3]': 0.32424714434060226,
#  'QuantileLoss[0.4]': 6192693.2614001855,
#  'Coverage[0.4]': 0.4313158285120902,
#  'QuantileLoss[0.5]': 6556604.13886298,
#  'Coverage[0.5]': 0.5332851209019434,
#  'QuantileLoss[0.6]': 6477612.845534541,
#  'Coverage[0.6]': 0.6188621866191959,
#  'QuantileLoss[0.7]': 5977663.537778089,
#  'Coverage[0.7]': 0.7144711467141374,
#  'QuantileLoss[0.8]': 4985227.292445754,
#  'Coverage[0.8]': 0.8057966177125055,
#  'QuantileLoss[0.9]': 3370831.9672860005,
#  'Coverage[0.9]': 0.8951379617267468,
#  'RMSE': 857.7857372661605,
#  'NRMSE': 0.3596175558562885,
#  'ND': 0.05097141770464814,
#  'wQuantileLoss[0.1]': 0.022417236291578355,
#  'wQuantileLoss[0.2]': 0.0347787061751353,
#  'wQuantileLoss[0.3]': 0.04307701598783941,
#  'wQuantileLoss[0.4]': 0.048142353670238176,
#  'wQuantileLoss[0.5]': 0.05097141776686668,
#  'wQuantileLoss[0.6]': 0.050357334908283855,
#  'wQuantileLoss[0.7]': 0.04647070022847091,
#  'wQuantileLoss[0.8]': 0.03875544376392745,
#  'wQuantileLoss[0.9]': 0.02620504163245693,
#  'mean_absolute_QuantileLoss': 5162115.566242433,
#  'mean_wQuantileLoss': 0.04013058338053301,
#  'MAE_Coverage': 0.39621841467635854,
#  'OWA': nan}

# %%
agg_metrics
# Out:
# {'MSE': 1699353.3605744469,
#  'abs_error': 7915254.201302687,
#  'abs_target_sum': 128632956.0,
#  'abs_target_mean': 2385.272140631954,
#  'seasonal_error': 189.49338196116761,
#  'MASE': 0.673017229115215,
#  'MAPE': 0.0925330129097111,
#  'sMAPE': 0.09874831644566463,
#  'MSIS': 5.436230429382124,
#  'QuantileLoss[0.1]': 3191534.9403455807,
#  'Coverage[0.1]': 0.08442738466102952,
#  'QuantileLoss[0.2]': 5158144.203989559,
#  'Coverage[0.2]': 0.1815198041833556,
#  'QuantileLoss[0.3]': 6537250.36521844,
#  'Coverage[0.3]': 0.2831367749592048,
#  'QuantileLoss[0.4]': 7449845.689399119,
#  'Coverage[0.4]': 0.3864040943480196,
#  'QuantileLoss[0.5]': 7915254.207095364,
#  'Coverage[0.5]': 0.49195223260643817,
#  'QuantileLoss[0.6]': 7986841.531431158,
#  'Coverage[0.6]': 0.5835929387331257,
#  'QuantileLoss[0.7]': 7462329.538075933,
#  'Coverage[0.7]': 0.6905689066904019,
#  'QuantileLoss[0.8]': 6362337.498570402,
#  'Coverage[0.8]': 0.7890149829402165,
#  'QuantileLoss[0.9]': 4403064.440043806,
#  'Coverage[0.9]': 0.8873127132472927,
#  'RMSE': 1303.5924825552067,
#  'NRMSE': 0.5465172968522716,
#  'ND': 0.06153364151332017,
#  'wQuantileLoss[0.1]': 0.024811176230340074,
#  'wQuantileLoss[0.2]': 0.0400997097819128,
#  'wQuantileLoss[0.3]': 0.050820960417161214,
#  'wQuantileLoss[0.4]': 0.05791552896754638,
#  'wQuantileLoss[0.5]': 0.061533641558352774,
#  'wQuantileLoss[0.6]': 0.06209016553604784,
#  'wQuantileLoss[0.7]': 0.058012579125336534,
#  'wQuantileLoss[0.8]': 0.04946117772937133,
#  'wQuantileLoss[0.9]': 0.03422967625842172,
#  'mean_absolute_QuantileLoss': 6274066.934907707,
#  'mean_wQuantileLoss': 0.04877495728938785,
#  'MAE_Coverage': 0.39013211030344985,
#  'OWA': nan}

# %%
plt.figure(figsize=(20, 15))
date_formater = mdates.DateFormatter('%b, %d')
plt.rcParams.update({'font.size': 15})

for idx, (forecast, ts) in islice(enumerate(zip(forecasts, tss)), 9):
    ax = plt.subplot(3, 3, idx+1)

    plt.plot(ts[-4 * dataset.metadata.prediction_length:].to_timestamp(), label="target", )
    forecast.plot( color='g')
    plt.xticks(rotation=60)
    ax.xaxis.set_major_formatter(date_formater)
    ax.set_title(forecast.item_id)

plt.gcf().tight_layout()
plt.legend()
plt.show()

# %%
crpss = []
for i in range(79):
    estimator = LagGPTAlibiEstimator(
        prediction_length=dataset.metadata.prediction_length,
        context_length=dataset.metadata.prediction_length*(i+1),
        
        scaling="std",
        # rope_scaling=dict(type="linear", factor=2.0),
        n_layer=4,
        
        batch_size=16,
        num_batches_per_epoch=100,
        trainer_kwargs=dict(accelerator="gpu", precision="bf16-mixed", max_epochs=0),
        ckpt_path='/mnt/scratch/kashif/pytorch-transformer-ts/lag-gpt-alibi/lightning_logs/version_14/checkpoints/epoch=49-step=5000.ckpt',
    )

    predictor = estimator.train(
            training_data=dataset.train,
            shuffle_buffer_length=1024,
            cache_data=True,
    )

    forecast_it, ts_it = make_evaluation_predictions(
        dataset=dataset.test,
        predictor=predictor,
    )

    forecasts = list(forecast_it)

    agg_metrics, _ = evaluator(iter(tss), iter(forecasts))

    
    crpss.append(agg_metrics["mean_wQuantileLoss"])
# Out:
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:70: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type             | Params
# -------------------------------------------
# 0 | model | LagGPTAlibiModel | 117 K
# -------------------------------------------
# 117 K     Trainable params
# 0         Non-trainable params
# 117 K     Total params
# 0.471     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=0` reached.
# Running evaluation: 2247it [00:00, 30077.87it/s]
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:138: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:70: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type             | Params
# -------------------------------------------
# 0 | model | LagGPTAlibiModel | 117 K
# -------------------------------------------
# 117 K     Trainable params
# 0         Non-trainable params
# 117 K     Total params
# 0.471     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=0` reached.
# Running evaluation: 2247it [00:00, 30324.86it/s]
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:138: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:70: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type             | Params
# -------------------------------------------
# 0 | model | LagGPTAlibiModel | 117 K
# -------------------------------------------
# 117 K     Trainable params
# 0         Non-trainable params
# 117 K     Total params
# 0.471     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=0` reached.
# Running evaluation: 2247it [00:00, 29672.85it/s]
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:138: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:70: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type             | Params
# -------------------------------------------
# 0 | model | LagGPTAlibiModel | 117 K
# -------------------------------------------
# 117 K     Trainable params
# 0         Non-trainable params
# 117 K     Total params
# 0.471     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=0` reached.
# Running evaluation: 2247it [00:00, 28706.06it/s]
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:138: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:70: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type             | Params
# -------------------------------------------
# 0 | model | LagGPTAlibiModel | 117 K
# -------------------------------------------
# 117 K     Trainable params
# 0         Non-trainable params
# 117 K     Total params
# 0.471     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=0` reached.
# Running evaluation: 2247it [00:00, 30180.07it/s]
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:138: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:70: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type             | Params
# -------------------------------------------
# 0 | model | LagGPTAlibiModel | 117 K
# -------------------------------------------
# 117 K     Trainable params
# 0         Non-trainable params
# 117 K     Total params
# 0.471     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=0` reached.
# Running evaluation: 2247it [00:00, 29678.74it/s]
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:138: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)
# Using bfloat16 Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:70: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type             | Params
# -------------------------------------------
# 0 | model | LagGPTAlibiModel | 117 K
# -------------------------------------------
# 117 K     Trainable params
# 0         Non-trainable params
# 117 K     Total params
# 0.471     Total estimated model params size (MB)
# `Trainer.fit` stopped: `max_epochs=0` reached.
# Running evaluation: 2247it [00:00, 30855.52it/s]
# Process SpawnPoolWorker-123:
# Process SpawnPoolWorker-122:
# Process SpawnPoolWorker-124:
# Process SpawnPoolWorker-128:
# Process SpawnPoolWorker-118:
# Process SpawnPoolWorker-121:
# Process SpawnPoolWorker-119:
# Process SpawnPoolWorker-117:
# Process SpawnPoolWorker-113:
# Process SpawnPoolWorker-116:
# Process SpawnPoolWorker-120:
# Process SpawnPoolWorker-114:
# Process SpawnPoolWorker-115:
# Process SpawnPoolWorker-127:
# Process SpawnPoolWorker-126:
# Process SpawnPoolWorker-125:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 58, in worker_function
#     return evaluator.get_metrics_per_ts(ts, forecast)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 486, in get_metrics_per_ts
#     metrics[f"Coverage[{quantile}]"] = coverage(
#   File "/home/kashif/gluon-ts-PR/src/gluonts/model/forecast.py", line 234, in __str__
#     def __str__(self):
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 58, in worker_function
#     return evaluator.get_metrics_per_ts(ts, forecast)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 397, in get_metrics_per_ts
#     if not validate_forecast(forecast, self.quantiles):
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 133, in validate_forecast
#     valid &= all(
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 134, in <genexpr>
#     ~np.isnan(forecast.quantile(q.value)).any() for q in quantiles
#   File "/home/kashif/gluon-ts-PR/src/gluonts/model/forecast.py", line 477, in quantile
#     q = Quantile.parse(q).value
#   File "/home/kashif/gluon-ts-PR/src/gluonts/model/forecast.py", line 230, in parse
#     return cls.from_float(quantile)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/model/forecast.py", line 177, in from_float
#     return cls(value=quantile, name=str(quantile))
#   File "pydantic/dataclasses.py", line 322, in pydantic.dataclasses._add_pydantic_validation_attributes.new_init
#   File "pydantic/dataclasses.py", line 286, in pydantic.dataclasses._add_pydantic_validation_attributes.handle_extra_init
#   File "<string>", line 2, in __init__
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 58, in worker_function
#     return evaluator.get_metrics_per_ts(ts, forecast)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 417, in get_metrics_per_ts
#     median_fcst = forecast.quantile(0.5)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/model/forecast.py", line 478, in quantile
#     sample_idx = int(np.round((self.num_samples - 1) * q))
#   File "<__array_function__ internals>", line 180, in round_
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 3731, in round_
#     return around(a, decimals=decimals, out=out)
#   File "<__array_function__ internals>", line 179, in around
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 3210, in _around_dispatcher
#     def _around_dispatcher(a, decimals=None, out=None):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/__init__.py", line 14, in <module>
#     from ._base import (
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 37, in <module>
#     from gluonts.model.forecast import Forecast, Quantile
#   File "/home/kashif/gluon-ts-PR/src/gluonts/model/__init__.py", line 27, in <module>
#     from .estimator import Estimator, IncrementallyTrainable
#   File "/home/kashif/gluon-ts-PR/src/gluonts/model/estimator.py", line 19, in <module>
#     from gluonts.dataset.common import Dataset
#   File "/home/kashif/gluon-ts-PR/src/gluonts/dataset/common.py", line 30, in <module>
#     from gluonts.dataset.schema import Translator
#   File "/home/kashif/gluon-ts-PR/src/gluonts/dataset/schema/__init__.py", line 15, in <module>
#     from .translate import Translator
#   File "/home/kashif/gluon-ts-PR/src/gluonts/dataset/schema/translate.py", line 117, in <module>
#     class Token:
#   File "/usr/lib/python3.10/dataclasses.py", line 1184, in dataclass
#     return wrap(cls)
#   File "/usr/lib/python3.10/dataclasses.py", line 1175, in wrap
#     return _process_class(cls, init, repr, eq, order, unsafe_hash,
#   File "/usr/lib/python3.10/dataclasses.py", line 1024, in _process_class
#     _init_fn(all_init_fields,
#   File "/usr/lib/python3.10/dataclasses.py", line 579, in _init_fn
#     return _create_fn('__init__',
#   File "/usr/lib/python3.10/dataclasses.py", line 432, in _create_fn
#     exec(txt, globals, ns)
#   File "<string>", line 1, in <module>
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 58, in worker_function
#     return evaluator.get_metrics_per_ts(ts, forecast)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 486, in get_metrics_per_ts
#     metrics[f"Coverage[{quantile}]"] = coverage(
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/metrics.py", line 90, in coverage
#     return np.mean(target <= forecast)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/ma/core.py", line 3076, in __array_wrap__
#     result._update_from(self)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/ma/core.py", line 2957, in _update_from
#     _optinfo.update(getattr(obj, '_optinfo', {}))
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 58, in worker_function
#     return evaluator.get_metrics_per_ts(ts, forecast)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 483, in get_metrics_per_ts
#     metrics[f"QuantileLoss[{quantile}]"] = quantile_loss(
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/metrics.py", line 81, in quantile_loss
#     return 2 * np.sum(np.abs((forecast - target) * ((target <= forecast) - q)))
#   File "<__array_function__ internals>", line 180, in sum
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 2298, in sum
#     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 84, in _wrapreduction
#     return reduction(axis=axis, out=out, **passkwargs)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/ma/core.py", line 5125, in sum
#     newmask = _check_mask_axis(_mask, axis, **kwargs)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/ma/core.py", line 1813, in _check_mask_axis
#     return mask.all(axis=axis, **kwargs)
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/__init__.py", line 14, in <module>
#     from ._base import (
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 37, in <module>
#     from gluonts.model.forecast import Forecast, Quantile
#   File "/home/kashif/gluon-ts-PR/src/gluonts/model/__init__.py", line 27, in <module>
#     from .estimator import Estimator, IncrementallyTrainable
#   File "/home/kashif/gluon-ts-PR/src/gluonts/model/estimator.py", line 19, in <module>
#     from gluonts.dataset.common import Dataset
#   File "/home/kashif/gluon-ts-PR/src/gluonts/dataset/common.py", line 30, in <module>
#     from gluonts.dataset.schema import Translator
#   File "/home/kashif/gluon-ts-PR/src/gluonts/dataset/schema/__init__.py", line 15, in <module>
#     from .translate import Translator
#   File "/home/kashif/gluon-ts-PR/src/gluonts/dataset/schema/translate.py", line 59, in <module>
#     class Method(Op):
#   File "/usr/lib/python3.10/dataclasses.py", line 1184, in dataclass
#     return wrap(cls)
#   File "/usr/lib/python3.10/dataclasses.py", line 1175, in wrap
#     return _process_class(cls, init, repr, eq, order, unsafe_hash,
#   File "/usr/lib/python3.10/dataclasses.py", line 1093, in _process_class
#     str(inspect.signature(cls)).replace(' -> None', ''))
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/inspect.py", line 3254, in signature
#     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#   File "/usr/lib/python3.10/inspect.py", line 3002, in from_callable
#     return _signature_from_callable(obj, sigcls=cls,
#   File "/usr/lib/python3.10/inspect.py", line 2501, in _signature_from_callable
#     sig = _get_signature_of(factory_method)
#   File "/usr/lib/python3.10/inspect.py", line 2463, in _signature_from_callable
#     return _signature_from_function(sigcls, obj,
#   File "/usr/lib/python3.10/inspect.py", line 2307, in _signature_from_function
#     annotations = get_annotations(func, globals=globals, locals=locals, eval_str=eval_str)
#   File "/usr/lib/python3.10/inspect.py", line 66, in get_annotations
#     def get_annotations(obj, *, globals=None, locals=None, eval_str=False):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/inspect.py", line 2421, in _signature_from_callable
#     sig = obj.__signature__
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 58, in worker_function
#     return evaluator.get_metrics_per_ts(ts, forecast)
# AttributeError: 'function' object has no attribute '__signature__'
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 486, in get_metrics_per_ts
#     metrics[f"Coverage[{quantile}]"] = coverage(
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/metrics.py", line 90, in coverage
#     return np.mean(target <= forecast)
#
# During handling of the above exception, another exception occurred:
#
#   File "<__array_function__ internals>", line 180, in mean
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 3430, in mean
#     return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# Traceback (most recent call last):
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/ma/core.py", line 5288, in mean
#     result = super().mean(axis=axis, dtype=dtype, **kwargs)[()]
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/core/_methods.py", line 182, in _mean
#     ret = um.true_divide(
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/ma/core.py", line 3065, in __array_wrap__
#     def __array_wrap__(self, obj, context=None):
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 58, in worker_function
#     return evaluator.get_metrics_per_ts(ts, forecast)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 486, in get_metrics_per_ts
#     metrics[f"Coverage[{quantile}]"] = coverage(
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/metrics.py", line 90, in coverage
#     return np.mean(target <= forecast)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/ma/core.py", line 3076, in __array_wrap__
#     result._update_from(self)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/ma/core.py", line 2951, in _update_from
#     if isinstance(obj, ndarray):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
# KeyboardInterrupt
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 58, in worker_function
#     return evaluator.get_metrics_per_ts(ts, forecast)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 486, in get_metrics_per_ts
#     metrics[f"Coverage[{quantile}]"] = coverage(
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/metrics.py", line 90, in coverage
#     return np.mean(target <= forecast)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/ma/core.py", line 3083, in __array_wrap__
#     m = reduce(mask_or, [getmaskarray(arg) for arg in input_args])
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/ma/core.py", line 1750, in mask_or
#     return make_mask(umath.logical_or(m1, m2), copy=copy, shrink=shrink)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/ma/core.py", line 1633, in make_mask
#     result = _shrink_mask(result)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 367, in get
#     return _ForkingPickler.loads(res)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/__init__.py", line 14, in <module>
#     from ._base import (
# KeyboardInterrupt
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 37, in <module>
#     from gluonts.model.forecast import Forecast, Quantile
#   File "/home/kashif/gluon-ts-PR/src/gluonts/model/__init__.py", line 27, in <module>
#     from .estimator import Estimator, IncrementallyTrainable
#   File "/home/kashif/gluon-ts-PR/src/gluonts/model/estimator.py", line 19, in <module>
#     from gluonts.dataset.common import Dataset
#   File "/home/kashif/gluon-ts-PR/src/gluonts/dataset/common.py", line 41, in <module>
#     from . import arrow
#   File "/home/kashif/gluon-ts-PR/src/gluonts/dataset/arrow/__init__.py", line 40, in <module>
#     from .file import File, ArrowFile, ArrowStreamFile, ParquetFile
#   File "/home/kashif/gluon-ts-PR/src/gluonts/dataset/arrow/file.py", line 67, in <module>
#     class ArrowFile(File):
#   File "/usr/lib/python3.10/dataclasses.py", line 1184, in dataclass
#     return wrap(cls)
#   File "/usr/lib/python3.10/dataclasses.py", line 1175, in wrap
#     return _process_class(cls, init, repr, eq, order, unsafe_hash,
#   File "/usr/lib/python3.10/dataclasses.py", line 1093, in _process_class
#     str(inspect.signature(cls)).replace(' -> None', ''))
#   File "/usr/lib/python3.10/inspect.py", line 3254, in signature
#     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#   File "/usr/lib/python3.10/inspect.py", line 3002, in from_callable
#     return _signature_from_callable(obj, sigcls=cls,
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/inspect.py", line 2501, in _signature_from_callable
#     sig = _get_signature_of(factory_method)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/inspect.py", line 2421, in _signature_from_callable
#     sig = obj.__signature__
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 58, in worker_function
#     return evaluator.get_metrics_per_ts(ts, forecast)
# KeyboardInterrupt
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 405, in get_metrics_per_ts
#     pred_target = np.array(self.extract_pred_target(time_series, forecast))
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 322, in extract_pred_target
#     assert forecast.index.intersection(time_series.index).equals(
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexes/datetimelike.py", line 161, in equals
#     return np.array_equal(self.asi8, other.asi8)
#   File "<__array_function__ internals>", line 180, in array_equal
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/core/numeric.py", line 2463, in array_equal
#     return bool(asarray(a1 == a2).all())
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/core/_methods.py", line 63, in _all
#     return umr_all(a, axis, dtype, out, keepdims)
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 58, in worker_function
#     return evaluator.get_metrics_per_ts(ts, forecast)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 405, in get_metrics_per_ts
#     pred_target = np.array(self.extract_pred_target(time_series, forecast))
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 332, in extract_pred_target
#     np.squeeze(time_series.loc[forecast.index].transpose())
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexing.py", line 1103, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexing.py", line 1332, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexing.py", line 1272, in _getitem_iterable
#     keyarr, indexer = self._get_listlike_indexer(key, axis)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexing.py", line 1462, in _get_listlike_indexer
#     keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 58, in worker_function
#     return evaluator.get_metrics_per_ts(ts, forecast)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 405, in get_metrics_per_ts
#     pred_target = np.array(self.extract_pred_target(time_series, forecast))
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 5872, in _get_indexer_strict
#     indexer = self.get_indexer_for(keyarr)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 332, in extract_pred_target
#     np.squeeze(time_series.loc[forecast.index].transpose())
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 5839, in get_indexer_for
#     @final
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexing.py", line 1103, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexing.py", line 1332, in _getitem_axis
#     return self._getitem_iterable(key, axis=axis)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexing.py", line 1272, in _getitem_iterable
#     keyarr, indexer = self._get_listlike_indexer(key, axis)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexing.py", line 1462, in _get_listlike_indexer
#     keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 5872, in _get_indexer_strict
#     indexer = self.get_indexer_for(keyarr)
# KeyboardInterrupt
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 5859, in get_indexer_for
#     return self.get_indexer(target)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3737, in get_indexer
#     if not self._should_compare(target) and not self._should_partial_index(target):
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 6090, in _should_compare
#     is_bool_dtype(self) and is_any_real_numeric_dtype(other)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/dtypes/common.py", line 1292, in is_bool_dtype
#     if isinstance(dtype, CategoricalDtype):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 58, in worker_function
#     return evaluator.get_metrics_per_ts(ts, forecast)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 486, in get_metrics_per_ts
#     metrics[f"Coverage[{quantile}]"] = coverage(
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/metrics.py", line 90, in coverage
#     return np.mean(target <= forecast)
#   File "<__array_function__ internals>", line 180, in mean
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/core/fromnumeric.py", line 3430, in mean
#     return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/ma/core.py", line 5288, in mean
#     result = super().mean(axis=axis, dtype=dtype, **kwargs)[()]
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/core/_methods.py", line 182, in _mean
#     ret = um.true_divide(
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/ma/core.py", line 3088, in __array_wrap__
#     with np.errstate(divide='ignore', invalid='ignore'):
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/core/_ufunc_config.py", line 430, in __enter__
#     self.oldstate = seterr(**self.kwargs)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/numpy/core/_ufunc_config.py", line 110, in seterr
#     old = geterr()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 58, in worker_function
#     return evaluator.get_metrics_per_ts(ts, forecast)
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 406, in get_metrics_per_ts
#     past_data = np.array(self.extract_past_data(time_series, forecast))
#   File "/home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py", line 367, in extract_past_data
#     np.squeeze(time_series.loc[:date_before_forecast].transpose())
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexing.py", line 1103, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexing.py", line 1323, in _getitem_axis
#     return self._get_slice_axis(key, axis=axis)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexing.py", line 1355, in _get_slice_axis
#     indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 6344, in slice_indexer
#     start_slice, end_slice = self.slice_locs(start, end, step=step)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 6543, in slice_locs
#     end_slice = self.get_slice_bound(end, "right")
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 6456, in get_slice_bound
#     slc = self.get_loc(label)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/indexes/period.py", line 404, in get_loc
#     if is_valid_na_for_dtype(key, self.dtype):
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/dtypes/missing.py", line 692, in is_valid_na_for_dtype
#     if not lib.is_scalar(obj) or not isna(obj):
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/dtypes/missing.py", line 183, in isna
#     return _isna(obj)
#   File "/home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/dtypes/missing.py", line 206, in _isna
#     return libmissing.checknull(obj, inf_as_na=inf_as_na)
# KeyboardInterrupt
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 30
#      23 forecast_it, ts_it = make_evaluation_predictions(
#      24     dataset=dataset.test,
#      25     predictor=predictor,
#      26 )
#      28 forecasts = list(forecast_it)
# ---> 30 agg_metrics, _ = evaluator(iter(tss), iter(forecasts))
#      33 crpss.append(agg_metrics["mean_wQuantileLoss"])
#
# File ~/gluon-ts-PR/src/gluonts/evaluation/_base.py:264, in Evaluator.__call__(self, ts_iterator, fcst_iterator, num_series)
#     260 if self.num_workers and not sys.platform == "win32":
#     261     mp_pool = multiprocessing.Pool(
#     262         initializer=None, processes=self.num_workers
#     263     )
# --> 264     rows = mp_pool.map(
#     265         func=partial(worker_function, self),
#     266         iterable=iter(it),
#     267         chunksize=self.chunk_size,
#     268     )
#     269     mp_pool.close()
#     270     mp_pool.join()
#
# File /usr/lib/python3.10/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /usr/lib/python3.10/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /usr/lib/python3.10/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /usr/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /usr/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
# /home/kashif/gluon-ts-PR/src/gluonts/evaluation/_base.py:425: RuntimeWarning: divide by zero encountered in float_scalars
#   metrics["ND"] = cast(float, metrics["abs_error"]) / cast(

# %%
plt.plot([(i+1)*24 for i in range(len(crpss))], crpss)
plt.xlabel("context_length")
plt.ylabel("CRPS")
# Out:
# Text(0, 0.5, 'CRPS')
