# %%
from itertools import islice

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib.dates as mdates

import pandas as pd
from sklearn.manifold import TSNE

# %%
from gluonts.dataset.repository.datasets import get_dataset
from gluonts.dataset.common import ListDataset
from gluonts.evaluation import make_evaluation_predictions, Evaluator
from gluonts.torch.distributions import NegativeBinomialOutput

from pytorch_lightning.loggers import CSVLogger
from datasets import load_dataset

from estimator import TransformerEstimator

# %%
dataset = get_dataset("wiki-rolling_nips")

# %%
estimator = TransformerEstimator(
        freq=dataset.metadata.freq,
        prediction_length=dataset.metadata.prediction_length,
        context_length=dataset.metadata.prediction_length*6,
        
        scaling=True,
        num_feat_static_cat=len(dataset.metadata.feat_static_cat),
        cardinality=[int(cat_feat_info.cardinality) for cat_feat_info in dataset.metadata.feat_static_cat],
        embedding_dimension=[6],
        
        nhead=2,
        num_encoder_layers=4,
        num_decoder_layers=2,
        dim_feedforward=16,
        activation="gelu",
        distr_output=NegativeBinomialOutput(),
        
        batch_size=256,
        num_batches_per_epoch=200,
        trainer_kwargs=dict(gpus="1", max_epochs=100, logger=CSVLogger(".", "lightning_logs/")),
    )

# %%
predictor = estimator.train(
        training_data=dataset.train,
        shuffle_buffer_length=1024,
        num_workers=8,
        cache_data=True,
    )
# Out:
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/utilities/parsing.py:262: UserWarning: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
#   rank_zero_warn(
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:446: LightningDeprecationWarning: Setting `Trainer(gpus='1')` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices='1')` instead.
#   rank_zero_deprecation(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:108: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type             | Params
# -------------------------------------------
# 0 | model | TransformerModel | 124 K
# -------------------------------------------
# 124 K     Trainable params
# 0         Non-trainable params
# 124 K     Total params
# 0.499     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 200: 'train_loss' reached 8.49763 (best 8.49763), saving model to './lightning_logs/version_410/checkpoints/epoch=0-step=200.ckpt' as top 1
# Epoch 1, global step 400: 'train_loss' reached 8.37025 (best 8.37025), saving model to './lightning_logs/version_410/checkpoints/epoch=1-step=400.ckpt' as top 1
# Epoch 2, global step 600: 'train_loss' reached 8.21840 (best 8.21840), saving model to './lightning_logs/version_410/checkpoints/epoch=2-step=600.ckpt' as top 1
# Epoch 3, global step 800: 'train_loss' was not in top 1
# Epoch 4, global step 1000: 'train_loss' was not in top 1
# Epoch 5, global step 1200: 'train_loss' reached 8.21630 (best 8.21630), saving model to './lightning_logs/version_410/checkpoints/epoch=5-step=1200.ckpt' as top 1
# Epoch 6, global step 1400: 'train_loss' was not in top 1
# Epoch 7, global step 1600: 'train_loss' reached 8.16992 (best 8.16992), saving model to './lightning_logs/version_410/checkpoints/epoch=7-step=1600.ckpt' as top 1
# Epoch 8, global step 1800: 'train_loss' was not in top 1
# Epoch 16, global step 3400: 'train_loss' was not in top 1
# Epoch 17, global step 3600: 'train_loss' was not in top 1
# Epoch 18, global step 3800: 'train_loss' was not in top 1
# Epoch 19, global step 4000: 'train_loss' was not in top 1
# Epoch 20, global step 4200: 'train_loss' reached 8.00247 (best 8.00247), saving model to './lightning_logs/version_410/checkpoints/epoch=20-step=4200.ckpt' as top 1
# Epoch 21, global step 4400: 'train_loss' reached 7.99510 (best 7.99510), saving model to './lightning_logs/version_410/checkpoints/epoch=21-step=4400.ckpt' as top 1
# Epoch 22, global step 4600: 'train_loss' reached 7.96470 (best 7.96470), saving model to './lightning_logs/version_410/checkpoints/epoch=22-step=4600.ckpt' as top 1
# Epoch 23, global step 4800: 'train_loss' was not in top 1
# Epoch 24, global step 5000: 'train_loss' was not in top 1
# Epoch 25, global step 5200: 'train_loss' was not in top 1
# Epoch 26, global step 5400: 'train_loss' was not in top 1
# Epoch 27, global step 5600: 'train_loss' reached 7.93751 (best 7.93751), saving model to './lightning_logs/version_410/checkpoints/epoch=27-step=5600.ckpt' as top 1
# Epoch 28, global step 5800: 'train_loss' was not in top 1
# Epoch 29, global step 6000: 'train_loss' reached 7.92754 (best 7.92754), saving model to './lightning_logs/version_410/checkpoints/epoch=29-step=6000.ckpt' as top 1
# Epoch 30, global step 6200: 'train_loss' was not in top 1
# Epoch 31, global step 6400: 'train_loss' was not in top 1
# Epoch 40, global step 8200: 'train_loss' reached 7.87317 (best 7.87317), saving model to './lightning_logs/version_410/checkpoints/epoch=40-step=8200.ckpt' as top 1
# Epoch 41, global step 8400: 'train_loss' was not in top 1
# Epoch 42, global step 8600: 'train_loss' reached 7.85237 (best 7.85237), saving model to './lightning_logs/version_410/checkpoints/epoch=42-step=8600.ckpt' as top 1
# Epoch 43, global step 8800: 'train_loss' was not in top 1
# Epoch 44, global step 9000: 'train_loss' was not in top 1
# Epoch 45, global step 9200: 'train_loss' was not in top 1
# Epoch 46, global step 9400: 'train_loss' reached 7.84024 (best 7.84024), saving model to './lightning_logs/version_410/checkpoints/epoch=46-step=9400.ckpt' as top 1
# Epoch 47, global step 9600: 'train_loss' reached 7.82934 (best 7.82934), saving model to './lightning_logs/version_410/checkpoints/epoch=47-step=9600.ckpt' as top 1
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Epoch 82, global step 16600: 'train_loss' was not in top 1
# Epoch 83, global step 16800: 'train_loss' was not in top 1
# Epoch 84, global step 17000: 'train_loss' reached 7.68940 (best 7.68940), saving model to './lightning_logs/version_410/checkpoints/epoch=84-step=17000.ckpt' as top 1
# Epoch 85, global step 17200: 'train_loss' was not in top 1
# Epoch 86, global step 17400: 'train_loss' was not in top 1
# Epoch 87, global step 17600: 'train_loss' reached 7.68176 (best 7.68176), saving model to './lightning_logs/version_410/checkpoints/epoch=87-step=17600.ckpt' as top 1
# Epoch 88, global step 17800: 'train_loss' was not in top 1
# Epoch 89, global step 18000: 'train_loss' reached 7.67841 (best 7.67841), saving model to './lightning_logs/version_410/checkpoints/epoch=89-step=18000.ckpt' as top 1
# Epoch 90, global step 18200: 'train_loss' was not in top 1
# Epoch 91, global step 18400: 'train_loss' was not in top 1
# Epoch 92, global step 18600: 'train_loss' reached 7.67326 (best 7.67326), saving model to './lightning_logs/version_410/checkpoints/epoch=92-step=18600.ckpt' as top 1
# Epoch 93, global step 18800: 'train_loss' was not in top 1
# Epoch 94, global step 19000: 'train_loss' was not in top 1

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=dataset.test,
    predictor=predictor,
)

# %%
forecasts = list(forecast_it)

# %%
tss = list(ts_it)

# %%
evaluator = Evaluator()

# %%
agg_metrics, ts_metrics = evaluator(iter(tss), iter(forecasts))
# Out:
# Running evaluation: 47675it [00:00, 99423.11it/s]

# %%
agg_metrics
# Out:
# {'MSE': 5329672770.079738,
#  'abs_error': 1633908755.0,
#  'abs_target_sum': 4139290389.0,
#  'abs_target_mean': 2894.1027016255903,
#  'seasonal_error': 759.9957754325233,
#  'MASE': 1.837933539590633,
#  'MAPE': 0.3401518161938212,
#  'sMAPE': 0.3546683416264892,
#  'MSIS': 84.20784472343651,
#  'QuantileLoss[0.1]': 567054904.8000001,
#  'Coverage[0.1]': 0.022811396608984447,
#  'QuantileLoss[0.2]': 938618779.2,
#  'Coverage[0.2]': 0.059279147002272325,
#  'QuantileLoss[0.3]': 1222516774.8,
#  'Coverage[0.3]': 0.12458870826778534,
#  'QuantileLoss[0.4]': 1446867315.2,
#  'Coverage[0.4]': 0.2218220590805803,
#  'QuantileLoss[0.5]': 1633908752.0,
#  'Coverage[0.5]': 0.3455270057682223,
#  'QuantileLoss[0.6]': 1775729844.0,
#  'Coverage[0.6]': 0.47103653207481205,
#  'QuantileLoss[0.7]': 1908557551.1999998,
#  'Coverage[0.7]': 0.6140108372662122,
#  'QuantileLoss[0.8]': 2015296926.7999997,
#  'Coverage[0.8]': 0.7498982695332984,
#  'QuantileLoss[0.9]': 2144020143.2,
#  'Coverage[0.9]': 0.8715923789547283,
#  'RMSE': 73004.60786881701,
#  'NRMSE': 25.22529965084204,
#  'ND': 0.39473160891104614,
#  'wQuantileLoss[0.1]': 0.13699326491007396,
#  'wQuantileLoss[0.2]': 0.22675837909182264,
#  'wQuantileLoss[0.3]': 0.29534453007906614,
#  'wQuantileLoss[0.4]': 0.349544771984346,
#  'wQuantileLoss[0.5]': 0.3947316081862842,
#  'wQuantileLoss[0.6]': 0.42899378326268955,
#  'wQuantileLoss[0.7]': 0.4610832707634902,
#  'wQuantileLoss[0.8]': 0.4868701486021786,
#  'wQuantileLoss[0.9]': 0.5179680432418196,
#  'mean_absolute_QuantileLoss': 1516952332.3555555,
#  'mean_wQuantileLoss': 0.36647642223575233,
#  'MAE_Coverage': 0.11327040727145604,
#  'OWA': nan}

# %%
plt.figure(figsize=(20, 15))
date_formater = mdates.DateFormatter('%b, %d')
plt.rcParams.update({'font.size': 15})

for idx, (forecast, ts) in islice(enumerate(zip(forecasts, tss)), 9):
    ax = plt.subplot(3, 3, idx+1)

    plt.plot(ts[-4 * dataset.metadata.prediction_length:].to_timestamp(), label="target", )
    forecast.plot( color='g')
    plt.xticks(rotation=60)
    ax.xaxis.set_major_formatter(date_formater)
    ax.set_title(forecast.item_id)

plt.gcf().tight_layout()
plt.legend()
plt.show()

# %%
metrics = pd.read_csv("lightning_logs/version_86/metrics.csv")

# %%
metrics
# Out:
#      train_perplexity  epoch  step  val_loss  train_loss
# 0            2.042362      0    49       NaN         NaN
# 1            2.050069      0    99       NaN         NaN
# 2            2.743227      0   149       NaN         NaN
# 3            2.440984      0   199       NaN         NaN
# 4                 NaN      0   199  4.355846         NaN
# ..                ...    ...   ...       ...         ...
# 295         80.659866     49  9899       NaN         NaN
# 296         82.568138     49  9949       NaN         NaN
# 297         81.211136     49  9999       NaN         NaN
# 298               NaN     49  9999  1.084462         NaN
# 299               NaN     49  9999       NaN    1.707654
#
# [300 rows x 5 columns]

# %%
ax = metrics.train_perplexity.dropna().plot(kind="line")
ax.set_xlabel("training steps")
ax.set_ylabel("perplexity")
# Out:
# Text(0, 0.5, 'perplexity')

# %%
ax = metrics.val_loss.dropna().plot()
ax.set_xlabel("training steps")
ax.set_ylabel("val neg. log likelihood")
# Out:
# Text(0, 0.5, 'val neg. log likelihood')

# %%
X = predictor.prediction_net.vq_vae.embed.cpu()

# %%
X_embedded = TSNE(n_components=2, learning_rate='auto', init='random').fit_transform(X)

# %%
plt.scatter(X_embedded[:,0], X_embedded[:,1], alpha=1.0)
