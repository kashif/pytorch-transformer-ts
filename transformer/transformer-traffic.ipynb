# %%
from itertools import islice

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib.dates as mdates

import pandas as pd
from sklearn.manifold import TSNE

# %%
from gluonts.dataset.repository.datasets import get_dataset
from gluonts.dataset.common import ListDataset
from gluonts.evaluation import make_evaluation_predictions, Evaluator
from pytorch_lightning.loggers import CSVLogger
from datasets import load_dataset

from estimator import TransformerEstimator

# %%
dataset = get_dataset("traffic")

# %%
estimator = TransformerEstimator(
        freq=dataset.metadata.freq,
        prediction_length=dataset.metadata.prediction_length,
        context_length=dataset.metadata.prediction_length*6,
        
        scaling=False,
        num_feat_static_cat=len(dataset.metadata.feat_static_cat),
        cardinality=[int(cat_feat_info.cardinality) for cat_feat_info in dataset.metadata.feat_static_cat],
        embedding_dimension=[3],
        
        nhead=2,
        num_encoder_layers=4,
        num_decoder_layers=2,
        dim_feedforward=16,
        activation="gelu",
        
        batch_size=256,
        num_batches_per_epoch=100,
        trainer_kwargs=dict(gpus="1", max_epochs=50, logger=CSVLogger(".", "lightning_logs/")),
    )

# %%
predictor = estimator.train(
        training_data=dataset.train,
        shuffle_buffer_length=1024,
        num_workers=8,
        cache_data=True,
    )
# Out:
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/utilities/parsing.py:262: UserWarning: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
#   rank_zero_warn(
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:446: LightningDeprecationWarning: Setting `Trainer(gpus='1')` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices='1')` instead.
#   rank_zero_deprecation(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/trainer/configuration_validator.py:108: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type             | Params
# -------------------------------------------
# 0 | model | TransformerModel | 95.9 K
# -------------------------------------------
# 95.9 K    Trainable params
# 0         Non-trainable params
# 95.9 K    Total params
# 0.384     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 100: 'train_loss' reached -0.80317 (best -0.80317), saving model to './lightning_logs/version_408/checkpoints/epoch=0-step=100.ckpt' as top 1
# Epoch 1, global step 200: 'train_loss' reached -1.70123 (best -1.70123), saving model to './lightning_logs/version_408/checkpoints/epoch=1-step=200.ckpt' as top 1
# Epoch 2, global step 300: 'train_loss' reached -1.98764 (best -1.98764), saving model to './lightning_logs/version_408/checkpoints/epoch=2-step=300.ckpt' as top 1
# Epoch 3, global step 400: 'train_loss' reached -2.16426 (best -2.16426), saving model to './lightning_logs/version_408/checkpoints/epoch=3-step=400.ckpt' as top 1
# Epoch 4, global step 500: 'train_loss' reached -2.33620 (best -2.33620), saving model to './lightning_logs/version_408/checkpoints/epoch=4-step=500.ckpt' as top 1
# Epoch 5, global step 600: 'train_loss' reached -2.47155 (best -2.47155), saving model to './lightning_logs/version_408/checkpoints/epoch=5-step=600.ckpt' as top 1
# Epoch 6, global step 700: 'train_loss' reached -2.56393 (best -2.56393), saving model to './lightning_logs/version_408/checkpoints/epoch=6-step=700.ckpt' as top 1
# Epoch 7, global step 800: 'train_loss' reached -2.63580 (best -2.63580), saving model to './lightning_logs/version_408/checkpoints/epoch=7-step=800.ckpt' as top 1
# Epoch 8, global step 900: 'train_loss' reached -2.70385 (best -2.70385), saving model to './lightning_logs/version_408/checkpoints/epoch=8-step=900.ckpt' as top 1
# Epoch 9, global step 1000: 'train_loss' reached -2.78450 (best -2.78450), saving model to './lightning_logs/version_408/checkpoints/epoch=9-step=1000.ckpt' as top 1
# Epoch 10, global step 1100: 'train_loss' reached -2.84855 (best -2.84855), saving model to './lightning_logs/version_408/checkpoints/epoch=10-step=1100.ckpt' as top 1
# Epoch 11, global step 1200: 'train_loss' reached -2.86754 (best -2.86754), saving model to './lightning_logs/version_408/checkpoints/epoch=11-step=1200.ckpt' as top 1
# Epoch 12, global step 1300: 'train_loss' reached -2.91637 (best -2.91637), saving model to './lightning_logs/version_408/checkpoints/epoch=12-step=1300.ckpt' as top 1
# Epoch 13, global step 1400: 'train_loss' reached -2.96008 (best -2.96008), saving model to './lightning_logs/version_408/checkpoints/epoch=13-step=1400.ckpt' as top 1
# Epoch 14, global step 1500: 'train_loss' reached -2.96684 (best -2.96684), saving model to './lightning_logs/version_408/checkpoints/epoch=14-step=1500.ckpt' as top 1
# Epoch 15, global step 1600: 'train_loss' reached -3.00469 (best -3.00469), saving model to './lightning_logs/version_408/checkpoints/epoch=15-step=1600.ckpt' as top 1
# Epoch 16, global step 1700: 'train_loss' reached -3.03272 (best -3.03272), saving model to './lightning_logs/version_408/checkpoints/epoch=16-step=1700.ckpt' as top 1
# Epoch 17, global step 1800: 'train_loss' reached -3.04566 (best -3.04566), saving model to './lightning_logs/version_408/checkpoints/epoch=17-step=1800.ckpt' as top 1
# Epoch 18, global step 1900: 'train_loss' reached -3.08181 (best -3.08181), saving model to './lightning_logs/version_408/checkpoints/epoch=18-step=1900.ckpt' as top 1
# Epoch 19, global step 2000: 'train_loss' reached -3.11124 (best -3.11124), saving model to './lightning_logs/version_408/checkpoints/epoch=19-step=2000.ckpt' as top 1
# Epoch 20, global step 2100: 'train_loss' was not in top 1
# Epoch 21, global step 2200: 'train_loss' reached -3.13779 (best -3.13779), saving model to './lightning_logs/version_408/checkpoints/epoch=21-step=2200.ckpt' as top 1
# Epoch 22, global step 2300: 'train_loss' reached -3.14998 (best -3.14998), saving model to './lightning_logs/version_408/checkpoints/epoch=22-step=2300.ckpt' as top 1
# Epoch 23, global step 2400: 'train_loss' reached -3.16326 (best -3.16326), saving model to './lightning_logs/version_408/checkpoints/epoch=23-step=2400.ckpt' as top 1
# Epoch 24, global step 2500: 'train_loss' reached -3.19947 (best -3.19947), saving model to './lightning_logs/version_408/checkpoints/epoch=24-step=2500.ckpt' as top 1
# Epoch 25, global step 2600: 'train_loss' reached -3.20617 (best -3.20617), saving model to './lightning_logs/version_408/checkpoints/epoch=25-step=2600.ckpt' as top 1
# Epoch 26, global step 2700: 'train_loss' reached -3.22491 (best -3.22491), saving model to './lightning_logs/version_408/checkpoints/epoch=26-step=2700.ckpt' as top 1
# Epoch 27, global step 2800: 'train_loss' was not in top 1
# Epoch 28, global step 2900: 'train_loss' reached -3.24536 (best -3.24536), saving model to './lightning_logs/version_408/checkpoints/epoch=28-step=2900.ckpt' as top 1
# Epoch 29, global step 3000: 'train_loss' reached -3.26488 (best -3.26488), saving model to './lightning_logs/version_408/checkpoints/epoch=29-step=3000.ckpt' as top 1
# Epoch 30, global step 3100: 'train_loss' reached -3.26722 (best -3.26722), saving model to './lightning_logs/version_408/checkpoints/epoch=30-step=3100.ckpt' as top 1
# Epoch 31, global step 3200: 'train_loss' reached -3.27890 (best -3.27890), saving model to './lightning_logs/version_408/checkpoints/epoch=31-step=3200.ckpt' as top 1
# Epoch 32, global step 3300: 'train_loss' reached -3.30499 (best -3.30499), saving model to './lightning_logs/version_408/checkpoints/epoch=32-step=3300.ckpt' as top 1
# Epoch 33, global step 3400: 'train_loss' was not in top 1
# Epoch 34, global step 3500: 'train_loss' reached -3.30603 (best -3.30603), saving model to './lightning_logs/version_408/checkpoints/epoch=34-step=3500.ckpt' as top 1
# Epoch 35, global step 3600: 'train_loss' reached -3.32444 (best -3.32444), saving model to './lightning_logs/version_408/checkpoints/epoch=35-step=3600.ckpt' as top 1
# Epoch 36, global step 3700: 'train_loss' reached -3.33797 (best -3.33797), saving model to './lightning_logs/version_408/checkpoints/epoch=36-step=3700.ckpt' as top 1
# Epoch 37, global step 3800: 'train_loss' was not in top 1
# Epoch 38, global step 3900: 'train_loss' was not in top 1
# Epoch 39, global step 4000: 'train_loss' reached -3.36589 (best -3.36589), saving model to './lightning_logs/version_408/checkpoints/epoch=39-step=4000.ckpt' as top 1
# Epoch 40, global step 4100: 'train_loss' was not in top 1
# Epoch 41, global step 4200: 'train_loss' was not in top 1
# Epoch 42, global step 4300: 'train_loss' reached -3.39399 (best -3.39399), saving model to './lightning_logs/version_408/checkpoints/epoch=42-step=4300.ckpt' as top 1
# Epoch 43, global step 4400: 'train_loss' reached -3.40453 (best -3.40453), saving model to './lightning_logs/version_408/checkpoints/epoch=43-step=4400.ckpt' as top 1
# Epoch 44, global step 4500: 'train_loss' was not in top 1
# Epoch 45, global step 4600: 'train_loss' reached -3.41286 (best -3.41286), saving model to './lightning_logs/version_408/checkpoints/epoch=45-step=4600.ckpt' as top 1
# Epoch 46, global step 4700: 'train_loss' reached -3.41784 (best -3.41784), saving model to './lightning_logs/version_408/checkpoints/epoch=46-step=4700.ckpt' as top 1
# Epoch 47, global step 4800: 'train_loss' was not in top 1
# Epoch 48, global step 4900: 'train_loss' reached -3.42195 (best -3.42195), saving model to './lightning_logs/version_408/checkpoints/epoch=48-step=4900.ckpt' as top 1
# Epoch 49, global step 5000: 'train_loss' reached -3.42953 (best -3.42953), saving model to './lightning_logs/version_408/checkpoints/epoch=49-step=5000.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=50` reached.
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pytorch_lightning/utilities/parsing.py:262: UserWarning: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
#   rank_zero_warn(

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=dataset.test,
    predictor=predictor,
)

# %%
forecasts = list(forecast_it)

# %%
tss = list(ts_it)

# %%
evaluator = Evaluator()

# %%
agg_metrics, ts_metrics = evaluator(iter(tss), iter(forecasts))
# Out:
# Running evaluation: 6034it [00:00, 10928.24it/s]
# /home/kashif/.env/pytorch/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:170: UserWarning: Warning: converting a masked element to nan.
#   return arr.astype(dtype, copy=True)

# %%
agg_metrics
# Out:
# {'MSE': 0.0009735079624914573,
#  'abs_error': 2557.504844032228,
#  'abs_target_sum': 8672.5710073933,
#  'abs_target_mean': 0.0598868288545002,
#  'seasonal_error': 0.015220711169889631,
#  'MASE': 1.3000324385806992,
#  'MAPE': 1.2105401288497324,
#  'sMAPE': 0.3941314951953486,
#  'MSIS': 11.508284072789623,
#  'QuantileLoss[0.1]': 1247.7999667831973,
#  'Coverage[0.1]': 0.3044207822340073,
#  'QuantileLoss[0.2]': 1838.6187099514589,
#  'Coverage[0.2]': 0.4167978676389349,
#  'QuantileLoss[0.3]': 2217.341031904658,
#  'Coverage[0.3]': 0.5013603469229919,
#  'QuantileLoss[0.4]': 2449.6894316156395,
#  'Coverage[0.4]': 0.5712697491989835,
#  'QuantileLoss[0.5]': 2557.504843601957,
#  'Coverage[0.5]': 0.6335556844547564,
#  'QuantileLoss[0.6]': 2545.3354630095882,
#  'Coverage[0.6]': 0.6856700917025744,
#  'QuantileLoss[0.7]': 2400.088776300754,
#  'Coverage[0.7]': 0.7447933929952493,
#  'QuantileLoss[0.8]': 2083.7158349916335,
#  'Coverage[0.8]': 0.8087227930615402,
#  'QuantileLoss[0.9]': 1500.0963136690668,
#  'Coverage[0.9]': 0.8867735609324936,
#  'RMSE': 0.031201089123481848,
#  'NRMSE': 0.5210008564535512,
#  'ND': 0.29489580908037244,
#  'wQuantileLoss[0.1]': 0.14387889885472915,
#  'wQuantileLoss[0.2]': 0.21200388078506943,
#  'wQuantileLoss[0.3]': 0.2556728598721638,
#  'wQuantileLoss[0.4]': 0.28246403857948216,
#  'wQuantileLoss[0.5]': 0.29489580903075957,
#  'wQuantileLoss[0.6]': 0.2934926056920963,
#  'wQuantileLoss[0.7]': 0.27674478240128525,
#  'wQuantileLoss[0.8]': 0.2402650647905081,
#  'wQuantileLoss[0.9]': 0.17297019677212747,
#  'mean_absolute_QuantileLoss': 2093.3544857586617,
#  'mean_wQuantileLoss': 0.24137645964202456,
#  'MAE_Coverage': 0.11997968303072717,
#  'OWA': nan}

# %%
plt.figure(figsize=(20, 15))
date_formater = mdates.DateFormatter('%b, %d')
plt.rcParams.update({'font.size': 15})

for idx, (forecast, ts) in islice(enumerate(zip(forecasts, tss)), 9):
    ax = plt.subplot(3, 3, idx+1)

    plt.plot(ts[-4 * dataset.metadata.prediction_length:].to_timestamp(), label="target", )
    forecast.plot( color='g')
    plt.xticks(rotation=60)
    ax.xaxis.set_major_formatter(date_formater)
    ax.set_title(forecast.item_id)

plt.gcf().tight_layout()
plt.legend()
plt.show()

# %%
metrics = pd.read_csv("lightning_logs/version_86/metrics.csv")

# %%
metrics
# Out:
#      train_perplexity  epoch  step  val_loss  train_loss
# 0            2.042362      0    49       NaN         NaN
# 1            2.050069      0    99       NaN         NaN
# 2            2.743227      0   149       NaN         NaN
# 3            2.440984      0   199       NaN         NaN
# 4                 NaN      0   199  4.355846         NaN
# ..                ...    ...   ...       ...         ...
# 295         80.659866     49  9899       NaN         NaN
# 296         82.568138     49  9949       NaN         NaN
# 297         81.211136     49  9999       NaN         NaN
# 298               NaN     49  9999  1.084462         NaN
# 299               NaN     49  9999       NaN    1.707654
#
# [300 rows x 5 columns]

# %%
ax = metrics.train_perplexity.dropna().plot(kind="line")
ax.set_xlabel("training steps")
ax.set_ylabel("perplexity")
# Out:
# Text(0, 0.5, 'perplexity')

# %%
ax = metrics.val_loss.dropna().plot()
ax.set_xlabel("training steps")
ax.set_ylabel("val neg. log likelihood")
# Out:
# Text(0, 0.5, 'val neg. log likelihood')

# %%
X = predictor.prediction_net.vq_vae.embed.cpu()

# %%
X_embedded = TSNE(n_components=2, learning_rate='auto', init='random').fit_transform(X)

# %%
plt.scatter(X_embedded[:,0], X_embedded[:,1], alpha=1.0)
